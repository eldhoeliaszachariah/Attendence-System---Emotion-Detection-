# %% [markdown]
# # code well with Cnn and Face_recognition

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26504\1616836296.py in <module>
#       1 import cv2
#       2 import numpy as np
# ----> 3 import face_recognition
#       4 import os
#       5 from datetime import datetime
#
# ModuleNotFoundError: No module named 'face_recognition'

# %%
import cv2
import numpy as np
import face_recognition
import os
from datetime import datetime, time
from keras.models import model_from_json

# Load the emotion detection model
json_file = open("facialemotionmodel.json", "r")
model_json = json_file.read()
json_file.close()
emotion_model = model_from_json(model_json)
emotion_model.load_weights("facialemotionmodel.h5")

# Path to the directory containing the training images
path = 'Training_images'
images = []
classNames = []
myList = os.listdir(path)
print(myList)
for cl in myList:
    curImg = cv2.imread(f'{path}/{cl}')
    images.append(curImg)
    classNames.append(os.path.splitext(cl)[0])
print(classNames)

def findEncodings(images):
    encodeList = []
    for img in images:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        encodings = face_recognition.face_encodings(img)
        if len(encodings) > 0:  # Ensure there is at least one encoding
            encodeList.append(encodings[0])
        else:
            print(f"No face found in one of the images, skipping this image.")
    return encodeList

def markAttendance(name, emotion):
    current_time = datetime.now().time()
    start_time = time(9, 30)
    end_time = time(10, 0)

    with open('Attendance.csv', 'r+') as f:
        myDataList = f.readlines()
        nameList = [line.split(',')[0] for line in myDataList]

        if current_time >= start_time and current_time <= end_time:
            if name not in nameList:
                now = datetime.now()
                dtString = now.strftime('%H:%M:%S')
                f.writelines(f'\n{name},{dtString},Present,{emotion}')
        elif current_time > end_time and name not in nameList:
            f.writelines(f'\n{name},-,Absent,-')

def extract_features(image):
    feature = np.array(image)
    feature = feature.reshape(1, 48, 48, 1)
    return feature / 255.0

# Get encodings of known faces
encodeListKnown = findEncodings(images)
print('Encoding Complete')

# Start webcam feed
cap = cv2.VideoCapture(0)

while True:
    success, img = cap.read()
    imgS = cv2.resize(img, (0, 0), None, 0.25, 0.25)
    imgS = cv2.cvtColor(imgS, cv2.COLOR_BGR2RGB)

    facesCurFrame = face_recognition.face_locations(imgS)
    encodesCurFrame = face_recognition.face_encodings(imgS, facesCurFrame)

    for encodeFace, faceLoc in zip(encodesCurFrame, facesCurFrame):
        matches = face_recognition.compare_faces(encodeListKnown, encodeFace)
        faceDis = face_recognition.face_distance(encodeListKnown, encodeFace)
        matchIndex = np.argmin(faceDis)

        if matches[matchIndex]:
            name = classNames[matchIndex].upper()
            y1, x2, y2, x1 = faceLoc
            y1, x2, y2, x1 = y1 * 4, x2 * 4, y2 * 4, x1 * 4
            
            # Extract the face ROI for emotion detection
            face_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            face_roi = face_gray[y1:y2, x1:x2]
            face_resized = cv2.resize(face_roi, (48, 48))
            face_features = extract_features(face_resized)
            
            # Predict emotion
            emotion_pred = emotion_model.predict(face_features)
            emotion_label = emotion_pred.argmax()

            # Convert emotion label to a human-readable string (assuming you have a dictionary for this)
            emotion_dict = {0: 'Angry', 1: 'Disgust', 2: 'Fear', 3: 'Happy', 4: 'Sad', 5: 'Surprise', 6: 'Neutral'}
            emotion_text = emotion_dict.get(emotion_label, "Unknown")

            cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.rectangle(img, (x1, y2 - 35), (x2, y2), (0, 255, 0), cv2.FILLED)
            cv2.putText(img, f'{name} | {emotion_text}', (x1 + 6, y2 - 6), cv2.FONT_HERSHEY_COMPLEX, 1, (255, 255, 255), 2)
            
            # Mark attendance with emotion
            markAttendance(name, emotion_text)

    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26504\633950222.py in <module>
#       1 import cv2
#       2 import numpy as np
# ----> 3 import face_recognition
#       4 import os
#       5 from datetime import datetime, time
#
# ModuleNotFoundError: No module named 'face_recognition'

# %%
pip install openpyxl

# %%
pip install pandas

# %%
import cv2 
import numpy as np
import mtcnn
from architecture import InceptionResNetV2
from train_v2 import normalize, l2_normalizer
from scipy.spatial.distance import cosine
from tensorflow.keras.models import model_from_json
from datetime import datetime, time
import pandas as pd
import pickle

# Load emotion detection model
json_file = open("facialemotionmodel.json", "r")
model_json = json_file.read()
json_file.close()
emotion_model = model_from_json(model_json)
emotion_model.load_weights("facialemotionmodel.h5")

# Load face recognition model
confidence_t = 0.99
recognition_t = 0.5
required_size = (160, 160)
face_encoder = InceptionResNetV2()
face_encoder.load_weights("facenet_keras_weights.h5")
face_detector = mtcnn.MTCNN()
encoding_dict = pickle.load(open('encodings/encodings.pkl', 'rb'))

# Emotion label dictionary
emotion_dict = {0: 'Angry', 1: 'Disgust', 2: 'Fear', 3: 'Happy', 4: 'Sad', 5: 'Surprise', 6: 'Neutral'}

# Create or load attendance dataframe
try:
    attendance_df = pd.read_excel("Attendance.xlsx")
except FileNotFoundError:
    attendance_df = pd.DataFrame(columns=['Name', 'Time', 'Status', 'Emotion'])

def save_attendance():
    attendance_df.to_excel("Attendance.xlsx", index=False)

def get_face(img, box):
    x1, y1, width, height = box
    x1, y1 = abs(x1), abs(y1)
    x2, y2 = x1 + width, y1 + height
    face = img[y1:y2, x1:x2]
    return face, (x1, y1), (x2, y2)

def get_encode(face_encoder, face, size):
    face = normalize(face)
    face = cv2.resize(face, size)
    encode = face_encoder.predict(np.expand_dims(face, axis=0))[0]
    return encode

def extract_features(image):
    feature = np.array(image)
    feature = feature.reshape(1, 48, 48, 1)
    return feature / 255.0

def mark_attendance(name, emotion):
    global attendance_df
    current_time = datetime.now().time()
    now = datetime.now().strftime('%H:%M:%S')
    start_time = time(9, 30)
    end_time = time(22, 19)

    # Check if the name is already marked
    if not ((attendance_df['Name'] == name) & (attendance_df['Status'] == 'Present')).any():
        if start_time <= current_time <= end_time:
            # Mark present
            new_entry = {'Name': name, 'Time': now, 'Status': 'Present', 'Emotion': emotion}
            attendance_df = pd.concat([attendance_df, pd.DataFrame([new_entry])], ignore_index=True)
        elif current_time > end_time and name not in attendance_df['Name'].values:
            # Mark absent if not detected by end time
            new_entry = {'Name': name, 'Time': now, 'Status': 'Absent', 'Emotion': 'N/A'}
            attendance_df = pd.concat([attendance_df, pd.DataFrame([new_entry])], ignore_index=True)

def mark_absent_for_undetected():
    global attendance_df
    current_time = datetime.now().strftime('%H:%M:%S')

    # For every name in the encoding dictionary, check if they are already marked as present
    for name in encoding_dict.keys():
        if not ((attendance_df['Name'] == name) & (attendance_df['Status'] == 'Present')).any():
            # If not marked, mark as absent
            new_entry = {'Name': name, 'Time': current_time, 'Status': 'Absent', 'Emotion': 'N/A'}
            attendance_df = pd.concat([attendance_df, pd.DataFrame([new_entry])], ignore_index=True)

    save_attendance()

def detect_and_recognize(img, detector, encoder, encoding_dict):
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = detector.detect_faces(img_rgb)
    for res in results:
        if res['confidence'] < confidence_t:
            continue
        face, pt_1, pt_2 = get_face(img_rgb, res['box'])
        encode = get_encode(encoder, face, required_size)
        encode = l2_normalizer.transform(encode.reshape(1, -1))[0]
        name = 'unknown'

        distance = float("inf")
        for db_name, db_encode in encoding_dict.items():
            dist = cosine(db_encode, encode)
            if dist < recognition_t and dist < distance:
                name = db_name
                distance = dist

        # Emotion detection
        face_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        face_roi = face_gray[pt_1[1]:pt_2[1], pt_1[0]:pt_2[0]]
        face_resized = cv2.resize(face_roi, (48, 48))
        face_features = extract_features(face_resized)
        emotion_pred = emotion_model.predict(face_features)
        emotion_label = emotion_pred.argmax()
        emotion_text = emotion_dict.get(emotion_label, "Unknown")

        # Attendance marking
        if name != 'unknown':
            mark_attendance(name, emotion_text)
            cv2.rectangle(img, pt_1, pt_2, (0, 255, 0), 2)
            cv2.putText(img, f'{name} | {emotion_text}', (pt_1[0], pt_1[1] - 5), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
        else:
            cv2.rectangle(img, pt_1, pt_2, (0, 0, 255), 2)
            cv2.putText(img, name, pt_1, cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 1)
    return img

if __name__ == "__main__":
    start_time = time(9, 30)
    end_time = time(22, 19)

    cap = cv2.VideoCapture(0)
    while cap.isOpened():
        current_time = datetime.now().time()

        if current_time > end_time:
            print("Attendance period has ended. Marking undetected faces as Absent.")
            mark_absent_for_undetected()  # Mark absent after the end time
            break  # Exit the loop after marking absences

        ret, frame = cap.read()
        if not ret:
            print("CAM NOT OPENED")
            break

        frame = detect_and_recognize(frame, face_detector, face_encoder, encoding_dict)
        cv2.imshow('camera', frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000021A86DEDC18> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
import numpy as np
import pickle
import tensorflow as tf
from sklearn.metrics import confusion_matrix
from keras.models import load_model
from sklearn.preprocessing import LabelEncoder

# Load the FaceNet model
model = load_model('facenet_keras_weights.h5')

# Load the encodings
with open('encodings/encodings.pkl', 'rb') as f:
    data = pickle.load(f)
    known_encodings = data['encodings']
    known_labels = data['labels']

# Prepare your test data (assuming you have a function to get encodings and labels from your test dataset)
def get_test_data():
    # Implement this function to load and preprocess your test dataset
    pass

test_images, test_labels = get_test_data()

# Encode the test images
def get_face_encoding(image):
    # Preprocess the image as required and get the encoding
    encoding = model.predict(image)  # Make sure to preprocess the image correctly before prediction
    return encoding

# Generate predictions
predictions = []
for image in test_images:
    encoding = get_face_encoding(image)
    # Compare encoding with known encodings
    distances = np.linalg.norm(known_encodings - encoding, axis=1)
    index = np.argmin(distances)
    predicted_label = known_labels[index]
    predictions.append(predicted_label)

# Compute confusion matrix
conf_matrix = confusion_matrix(test_labels, predictions)
print(conf_matrix)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_42356\2032749470.py in <module>
#       7
#       8 # Load the FaceNet model
# ----> 9 model = load_model('facenet_keras_weights.h5')
#      10
#      11 # Load the encodings
#
# ~\anaconda3\envs\attendence2\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~\anaconda3\envs\attendence2\lib\site-packages\keras\saving\legacy\hdf5_format.py in load_model_from_hdf5(filepath, custom_objects, compile)
#     187         if model_config is None:
#     188             raise ValueError(
# ...

# %%
from keras.models import load_model
import architecture  # Import your architecture script

# Create model from architecture.py
model = architecture.InceptionResNetV2()

# Load weights
model.load_weights('facenet_keras_weights.h5')

# %%
from keras.models import model_from_json

# Load model architecture from JSON file
with open('model_architecture.json', 'r') as json_file:
    model_json = json_file.read()
model = model_from_json(model_json)

# Load model weights
model.load_weights('facenet_keras_weights.h5')

# %%
pip install git+https://github.com/remykarem/python2jupyter#egg=p2j
# Out:
# ...
#   Cloning https://github.com/remykarem/python2jupyter to c:\users\arjun\appdata\local\temp\pip-install-kbkkhk8a\p2j_90a1ad96fff44e358c4d3a4f4c62ea4b
#   Resolved https://github.com/remykarem/python2jupyter to commit 065420bee214fc2d0ef0c69c0714521f3c6a3428
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for p2j: filename=p2j-1.3.3-py3-none-any.whl size=10187 sha256=8582508bde19877305c18663678db9eb044365b9de4adcc1e79d0396e65b6599
#   Stored in directory: C:\Users\Arjun\AppData\Local\Temp\pip-ephem-wheel-cache-x_gxnk94\wheels\1c\f9\1f\9e14639e2412fc866883a3af2e04134319fc98f01358253562
# Successfully built p2j
# ...
#   Attempting uninstall: p2j
#     Found existing installation: p2j 1.3.2
#     Uninstalling p2j-1.3.2:
#       Successfully uninstalled p2j-1.3.2
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
p2j architecture2.py
# Out:
#   File "C:\Users\Arjun\AppData\Local\Temp\ipykernel_19328\2445726853.py", line 1
#     p2j architecture2.py
#                     ^
# SyntaxError: invalid syntax

# %%
import pickle

# Load the encodings and labels
with open('encodings/encodings.pkl', 'rb') as f:
    data = pickle.load(f)

# Assuming the data is stored as a dictionary with keys 'encodings' and 'labels'
face_encodings = data['encodings']  # Face embeddings (features)
true_labels = data['labels']        # Corresponding true labels
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12476\3191025515.py in <module>
#       6
#       7 # Assuming the data is stored as a dictionary with keys 'encodings' and 'labels'
# ----> 8 face_encodings = data['encodings']  # Face embeddings (features)
#       9 true_labels = data['labels']        # Corresponding true labels
#
# KeyError: 'encodings'

# %%
from architecture import *  # Assuming this contains necessary imports
import os 
import cv2
import mtcnn
import pickle 
import numpy as np 
from sklearn.preprocessing import Normalizer
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model

###### Paths and Variables #########
face_data = 'Faces/'  # Directory with test faces (labeled folders)
required_shape = (160,160)
face_encoder = InceptionResNetV2()
path = "facenet_keras_weights.h5"
face_encoder.load_weights(path)
face_detector = mtcnn.MTCNN()
l2_normalizer = Normalizer('l2')

# Load saved encodings (dictionary of {person_name: encoding})
with open('encodings/encodings.pkl', 'rb') as file:
    encoding_dict = pickle.load(file)

# Ground truth labels and predicted labels
y_true = []
y_pred = []

def normalize(img):
    mean, std = img.mean(), img.std()
    return (img - mean) / std

def find_closest_match(encoding, encoding_dict):
    """Find the closest match in the encoding_dict based on cosine similarity."""
    min_dist = float("inf")
    match_name = None
    
    for name, db_encode in encoding_dict.items():
        dist = np.linalg.norm(encoding - db_encode)
        if dist < min_dist:
            min_dist = dist
            match_name = name
    
    return match_name

###### Prediction Loop #########
for face_names in os.listdir(face_data):
    person_dir = os.path.join(face_data, face_names)

    for image_name in os.listdir(person_dir):
        image_path = os.path.join(person_dir, image_name)

        # Read and preprocess the image
        img_BGR = cv2.imread(image_path)
        img_RGB = cv2.cvtColor(img_BGR, cv2.COLOR_BGR2RGB)

        # Detect face
        detection = face_detector.detect_faces(img_RGB)
        if detection:
            x1, y1, width, height = detection[0]['box']
            x1, y1 = abs(x1), abs(y1)
            x2, y2 = x1 + width, y1 + height
            face = img_RGB[y1:y2, x1:x2]

            # Normalize and resize face
            face = normalize(face)
            face = cv2.resize(face, required_shape)
            face_d = np.expand_dims(face, axis=0)

            # Get the encoding of the face
            encode = face_encoder.predict(face_d)[0]
            encode = l2_normalizer.transform(np.expand_dims(encode, axis=0))[0]

            # Find the closest match in encoding_dict
            predicted_name = find_closest_match(encode, encoding_dict)

            # Append the true label and predicted label
            y_true.append(face_names)  # Ground truth from folder name
            y_pred.append(predicted_name)
# Out:
# ...
# 1/1 [==============================] - 0s 96ms/step
# Classification Report:
#                  precision    recall  f1-score   support
#
# Angelina Jolie       1.00      1.00      1.00        14
#      Brad Pitt       1.00      1.00      1.00        14
#   Hugh Jackman       1.00      0.79      0.88        14
#      Tom Hanks       0.57      0.29      0.38        14
#     Will Smith       0.58      1.00      0.74        14
#
#       accuracy                           0.81        70
#      macro avg       0.83      0.81      0.80        70
#   weighted avg       0.83      0.81      0.80        70

# %%
# Create confusion matrix and classification report
cm = confusion_matrix(y_true, y_pred)
print("Classification Report:\n", classification_report(y_true, y_pred))

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=list(encoding_dict.keys()), yticklabels=list(encoding_dict.keys()))
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Classification Report:
#                  precision    recall  f1-score   support
#
# Angelina Jolie       1.00      1.00      1.00        14
#      Brad Pitt       1.00      1.00      1.00        14
#   Hugh Jackman       1.00      0.79      0.88        14
#      Tom Hanks       0.57      0.29      0.38        14
#     Will Smith       0.58      1.00      0.74        14
#
#       accuracy                           0.81        70
#      macro avg       0.83      0.81      0.80        70
#   weighted avg       0.83      0.81      0.80        70

# %%
pip install seaborn
# Out:
# ...
#
#   Using cached seaborn-0.12.2-py3-none-any.whl (293 kB)
# ...
